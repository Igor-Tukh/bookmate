# %%
import os
import numpy as np
import nltk
import re
import pickle

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/itukh/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
RESOURCES_PATH = './resources'

# %%
def load_text(text_path, encoding='utf-8'):
    with open(text_path, 'r', encoding=encoding) as text_file:
        return text_file.read()

# %%
def save_chunks(output_path, chunks):
    for ind, chunk in enumerate(chunks):
        with open(os.path.join(output_path, f'text_{ind}.txt'), 'w') as output_file:
            output_file.write(chunk)

# %%
def split_text(text, chunks_number=400, bias=0):
    lines = text.split(os.linesep)
    lens = [len(line) + 1 for line in lines]
    chunks = []
    deltas = []
    n_words = []
    
    avg_size = 1. * len(text) / chunks_number
    n = len(lines)
    
    cur_len = 0
    cur_ind = 0
    chapter_ind = 1
    min_len = 1000000000
    max_len = -1
    for chunk_ind in range(chunks_number):
        if len(chunks) == 0 or chunks[-1] != []:
            chunks.append([])
        while cur_ind < n and cur_len < avg_size + bias:
            if (lines[cur_ind] == f'Глава {chapter_ind}'):
                chapter_ind += 1
                break
            chunks[-1].append(lines[cur_ind])
            cur_len += lens[cur_ind]
            cur_ind += 1
        if cur_len != 0:
            chunks[-1] = os.linesep.join(chunks[-1]) + os.linesep
            min_len = min(min_len, len(chunks[-1]))
            max_len = max(max_len, len(chunks[-1]))
            deltas.append((len(chunks[-1]) - avg_size) ** 2)
            n_words.append(len([word for word in re.split('\W+', chunks[-1]) if word != '']))
            cur_len = 0
            
    chunk_ind = len(chunks)
    while chunk_ind > 0 and len(chunks[chunk_ind - 1]) == 0:
        chunk_ind -= 1
    chunks = chunks[:chunk_ind]
    chunks[-1] = chunks[-1][:-1]
    
    mse = np.sqrt(np.array(deltas).mean())
    print(f'Expected chunk len: {avg_size}')
    print(f'Min len: {min_len}')
    print(f'Max len: {max_len}')
    print(f'Mean square error: {mse}')
    print(f'Average words number : {np.array(n_words).mean()}')
    return chunks, mse, avg_size

# %%
text = load_text(os.path.join(RESOURCES_PATH, '215591.txt'))

# %%
chunks, _, avg_size = split_text(text)
# Out:
# Expected chunk len: 2328.545
# Min len: 5
# Max len: 3741
# Mean square error: 375.6759329442437
# Average words number : 367.2817258883249

# %%
print(sum([len(chunk) for chunk in chunks]), len(text))
# Out:
# 931418 931418

# %%
def join_chunks(chunks, avg_size):
    cur_ind = 0
    final_chunks = []
    
    lens = []
    while cur_ind < len(chunks):
        chunk = chunks[cur_ind]
        if len(chunk) < 100 and len(final_chunks) > 0:
            final_chunks[-1] += chunk
            cur_ind += 1
            continue
        if len(chunk) > avg_size / 2 or cur_ind == len(chunks) - 1 or 'Глава' in chunks[cur_ind + 1]:
            final_chunks.append(chunk)
            cur_ind += 1
        else:
            final_chunks.append(chunk + chunks[cur_ind + 1])
            cur_ind += 2
        lens.append(len(final_chunks[-1]))
    print(f'Min len: {min(lens)}')
    print(f'Max lenL {max(lens)}')
    
    return final_chunks

# %%
chunks = join_chunks(chunks, avg_size)
# Out:
# Min len: 223
# Max lenL 3741

# %%
cur_len = 0
next_len = 0

pos = []

for chunk in chunks:
# [0.8646794457483103; 0.8657283840338063)
# [0.8657283840338063; 0.8682546396998981)
# [0.8682546396998981; 0.8707690854159998)
# [0.8707690854159998; 0.8733941152092828)
# [0.8733941152092828; 0.8763423081795712)
# [0.8763423081795712; 0.8791831379681301)
# [0.8791831379681301; 0.8817802533341633)
# [0.8817802533341633; 0.884492247304647)
# [0.884492247304647; 0.8871559278433525)
# [0.8871559278433525; 0.8896939934594347)
# [0.8896939934594347; 0.892218101861892)
# [0.892218101861892; 0.895172736623084)
# [0.895172736623084; 0.8976818141800993)
# [0.8976818141800993; 0.9004131335232943)
# [0.9004131335232943; 0.9030209852075005)
# [0.9030209852075005; 0.9056062906235436)
# [0.9056062906235436; 0.9085813243892642)
# [0.9085813243892642; 0.911147304432596)
# [0.911147304432596; 0.9136896645759472)
# [0.9136896645759472; 0.9164381620282189)
# [0.9164381620282189; 0.9189569022715898)
# [0.9189569022715898; 0.9200036932934511)
# [0.9200036932934511; 0.9225363907504468)
# [0.9225363907504468; 0.9252043658164215)
# [0.9252043658164215; 0.9277896712324646)
# [0.9277896712324646; 0.9303373995349024)
# [0.9303373995349024; 0.9328507716191867)
# [0.9328507716191867; 0.9353523337534809)
# [0.9353523337534809; 0.9378603376786788)
# [0.9378603376786788; 0.9404069923492994)
# [0.9404069923492994; 0.942942910701747)
# [0.942942910701747; 0.9458427902402571)
# [0.9458427902402571; 0.9484839245107994)
# [0.9484839245107994; 0.9510295055496026)
# [0.9510295055496026; 0.9535707920611367)
# [0.9535707920611367; 0.9561689810589873)
# [0.9561689810589873; 0.9587381819977709)
# [0.9587381819977709; 0.9614652068136967)
# [0.9614652068136967; 0.964369380879476)
# [0.964369380879476; 0.9668773848046739)
# [0.9668773848046739; 0.9693929041525928)
# [0.9693929041525928; 0.9721081190185284)
# [0.9721081190185284; 0.9746740990618602)
# [0.9746740990618602; 0.9771756611961544)
# [0.9771756611961544; 0.9797255367622267)
# [0.9797255367622267; 0.9828379954005609)
# [0.9828379954005609; 0.9855650202164867)
# [0.9855650202164867; 0.9880837604598576)
# [0.9880837604598576; 0.9906164579168533)
# [0.9906164579168533; 0.9933263046237024)
# [0.9933263046237024; 0.9959695861578793)
# [0.9959695861578793; 0.9986354139602194)
# [0.9986354139602194; 0.9999999999999996)

# %%
print(sum([len(chunk) for chunk in chunks]))
# Out:
# 931418

# %%
with open(os.path.join(RESOURCES_PATH, 'chunks_poses.pkl'), 'wb') as chunks_file:
    pickle.dump(pos, chunks_file)

# %%
save_chunks(os.path.join(RESOURCES_PATH, '215591'), chunks)

# %%
count = 0

for ind, chunk in enumerate(chunks):
    if 'Глава' in chunk:
        print(ind)
        count += 1

print(f'Total {count} fragments with \'Глава\'')
# Out:
# 2
# 16
# 27
# 42
# 56
# 77
# 87
# 108
# 128
# 141
# 156
# 171
# 185
# 200
# 211
# 223
# 237
# 249
# 263
# 275
# 286
# 299
# 311
# 325
# 341
# 362
# 391
# Total 27 fragments with 'Глава'
